# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# 2020-02-20-flights.json    SFO_3-5-2020-flights.json
# 2020-02-20.csv             to_json.ipynb
# 3-5-2020_SFO.json

# %%
df_test = pd.read_csv("2020-02-20.csv")

# %%
df_test
# Out:
#        to_location  legs_outbound from_location  local_price  \
# 0              OPO              1           CGN        61.25
# 1              GVA              1           AMS       109.95
# 2              DTM              1           KTW        78.57
# 3              DXB              2           HKG      2987.47
# 4              JFK              2           AMS       266.43
# ...            ...            ...           ...          ...
# 116875         ATH              1           LHR       158.72
# 116876         GYD              1           OVB     20511.94
# 116877         CGH              1           POA       322.80
# 116878         HAN              2           AMS       486.09
# 116879         NAT              1           GIG       641.46
#
#        outbound_departure_dt local_ccy inbound_departure_dt destination_city  \
# 0        2020-03-30 14:10:00       EUR  2020-04-06 10:10:00            Porto
# ...

# %%
df_test.to_json("2020-02-20-flights.json", orient='records')

# %%
df_test
